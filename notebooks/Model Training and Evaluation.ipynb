# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: ",device)
# Out:
# Using device:  cpu

# %%
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader, random_split, WeightedRandomSampler

import matplotlib.pyplot as plt
import numpy as np
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ###############################updated
# data_dir = "/content/drive/MyDrive/RecycleVision/datas/garbage-dataset"

# train_transform = transforms.Compose([
#     transforms.RandomResizedCrop(224, scale=(0.8,1.0)),
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomRotation(20),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485,0.456,0.406],
#                          std=[0.229,0.224,0.225])
# ])

# val_transform = transforms.Compose([
#     transforms.Resize((224,224)),
#     transforms.ToTensor(),
#     transforms.Normalize(mean = [0.485,0.456,0.406],
#                          std = [0.229,0.224,0.225])
# ])

# #loading data and spliiting it
# full_dataset = datasets.ImageFolder(data_dir, transform=train_transform)

# train_size = int(0.8 * len(full_dataset))
# val_size = len(full_dataset) - train_size
# train_dataset, val_dataset = random_split(
#     full_dataset, [train_size, val_size]
# )

# val_dataset.dataset.transform = val_transform

# #handling imbalance with weightRandomSampler
# labels = [label for _, label in full_dataset.samples]
# class_counts = np.bincount(labels)
# class_weights = 1.0/class_counts

# # use correct indices for train subset
# train_indices = train_dataset.indices
# sample_weights = [class_weights[label] for _, label in full_dataset.samples]
# train_weights = [sample_weights[idx] for idx in train_indices]

# train_sampler = WeightedRandomSampler(
#     weights = sample_weights[:len(train_dataset)],
#     num_samples=len(train_dataset),
#     replacement=True
# )

# #dataloaders
# train_loader = DataLoader(train_dataset,batch_size=32, sampler=train_sampler, num_workers=0, pin_memory=True)
# val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=0, pin_memory=True)

# print("Train batches:", len(train_loader))
# print("Validation batches:", len(val_loader))
# Out:
# Train batches: 495
# Validation batches: 124

# %%
data_dir = "/content/drive/MyDrive/RecycleVision/datas/garbage-dataset"

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8,1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406],
                         std=[0.229,0.224,0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean = [0.485,0.456,0.406],
                         std = [0.229,0.224,0.225])
])

#loading data and spliiting it
full_dataset = datasets.ImageFolder(data_dir, transform=train_transform)

train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(
    full_dataset, [train_size, val_size]
)

val_dataset.dataset.transform = val_transform



#dataloaders
train_loader = DataLoader(train_dataset,batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

print("Train batches:", len(train_loader))
print("Validation batches:", len(val_loader))
# Out:
# Train batches: 495
# Validation batches: 124

# %%
def train_an_epoch(model, dataloader, criterion, optimizer,device):
  model.train()
  running_loss, correct, total = 0.0,0,0
  batch = 0

  for batch_idx, (images, labels) in enumerate(dataloader, start=1):

    images, labels = images.to(device), labels.to(device)

    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs,labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item() * images.size(0)
    _, preds = torch.max(outputs, 1)
    correct += (preds == labels).sum().item()
    total += labels.size(0)

    if batch_idx % 32 == 0:  # every 32 batches
      print(f"  [Batch {batch_idx}/{len(dataloader)}] running...")

  epoch_loss = running_loss/total
  epoch_acc = correct/total
  return epoch_loss, epoch_acc


def evaluate(model, dataloader, criterion, device):
  model.eval()
  running_loss, correct, total = 0.0,0,0

  with torch.no_grad():
    for images, labels in dataloader:
      images, labels = images.to(device), labels.to(device)

      outputs = model(images)
      loss = criterion(outputs, labels)

      running_loss += loss.item() * images.size(0)
      _,preds = torch.max(outputs, 1)
      correct += (preds == labels).sum().item()
      total+= labels.size(0)

    epoch_loss = running_loss /total
    epoch_acc = correct/total
    return epoch_loss, epoch_acc

# %%
# class BaselineCNN(nn.Module):
#   def __init__(self):

#     super().__init__()

#     self.conv1 = nn.Conv2d(3,32, kernel_size=3, stride=1,padding=1) #32,224,224
#     self.pool = nn.MaxPool2d(2,2)                 #32,112,112
#     self.conv2 = nn.Conv2d(32,64, kernel_size=3, stride=1, padding=1) #64,112,112
#     #after pooling 64,56,56
#     self.conv3 = nn.Conv2d(64,128, kernel_size=3, stride=1, padding=1) #128,56,56
#     # after pooling 128, 28,28

#     self.fc1 = nn.Linear(128*28*28, 256)
#     self.fc2 = nn.Linear(256, 10)

#     self.relu = nn.ReLU()
#     self.drop = nn.Dropout(0.5)

#   def forward(self, x):
#     #conv1
#     x = self.conv1(x)
#     x = self.relu(x)
#     x = self.pool(x)

#     #conv2 + relu + pool
#     x = self.pool(self.relu(self.conv2(x)))

#     #conv3 + relu + pool
#     x = self.pool(self.relu(self.conv3(x)))

#     #flatten
#     x = x.view(-1, 128*28*28)

#     #fc1+relu+dropout
#     x = self.fc1(x)
#     x = self.relu(x)
#     x = self.drop(x)

#     #output
#     x=self.fc2(x)

#     return x



# #initializing model, loss, optimizer
# model = BaselineCNN().to(device)
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(model.parameters(), lr=0.001)

# import time

# #trainingLoop
# epochs = 1
# for epoch in range(epochs):
#   start = time.time()

#   train_loss, train_acc = train_an_epoch(model, train_loader, criterion, optimizer, device)
#   val_loss, val_acc = evaluate(model, val_loader, criterion, device)

#   duration = time.time() - start

#   print(f"Epoch [{epoch+1}/{epochs}] "
#           f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} "
#           f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f} "
#           f"Time: {duration:.2f}s")
# Out:
#   [Batch 0/495] running...
#   [Batch 5/495] running...
#   [Batch 10/495] running...
#   [Batch 15/495] running...
#   [Batch 20/495] running...
#   [Batch 25/495] running...
#   [Batch 30/495] running...
#   [Batch 35/495] running...
#   [Batch 40/495] running...
#   [Batch 45/495] running...
#   [Batch 50/495] running...
#   [Batch 55/495] running...
#   [Batch 60/495] running...
#   [Batch 65/495] running...
#   [Batch 70/495] running...
#   [Batch 75/495] running...
#   [Batch 80/495] running...
#   [Batch 85/495] running...
#   [Batch 90/495] running...
#   [Batch 95/495] running...
#   [Batch 100/495] running...
#   [Batch 105/495] running...
#   [Batch 110/495] running...
#   [Batch 115/495] running...
#   [Batch 120/495] running...
#   [Batch 125/495] running...
#   [Batch 130/495] running...
#   [Batch 135/495] running...
#   [Batch 140/495] running...
#   [Batch 145/495] running...
#   [Batch 150/495] running...
#   [Batch 155/495] running...
#   [Batch 160/495] running...
#   [Batch 165/495] running...
#   [Batch 170/495] running...
#   [Batch 175/495] running...
#   [Batch 180/495] running...
#   [Batch 185/495] running...
#   [Batch 190/495] running...
#   [Batch 195/495] running...
#   [Batch 200/495] running...
#   [Batch 205/495] running...
#   [Batch 210/495] running...
#   [Batch 215/495] running...
#   [Batch 220/495] running...
#   [Batch 225/495] running...
#   [Batch 230/495] running...
#   [Batch 235/495] running...
#   [Batch 240/495] running...
#   [Batch 245/495] running...
#   [Batch 250/495] running...
#   [Batch 255/495] running...
#   [Batch 260/495] running...
#   [Batch 265/495] running...
#   [Batch 270/495] running...
#   [Batch 275/495] running...
#   [Batch 280/495] running...
#   [Batch 285/495] running...
#   [Batch 290/495] running...
#   [Batch 295/495] running...
#   [Batch 300/495] running...
#   [Batch 305/495] running...
#   [Batch 310/495] running...
#   [Batch 315/495] running...
#   [Batch 320/495] running...
#   [Batch 325/495] running...
#   [Batch 330/495] running...
#   [Batch 335/495] running...
#   [Batch 340/495] running...
#   [Batch 345/495] running...
#   [Batch 350/495] running...
#   [Batch 355/495] running...
#   [Batch 360/495] running...
#   [Batch 365/495] running...
#   [Batch 370/495] running...
#   [Batch 375/495] running...
#   [Batch 380/495] running...
#   [Batch 385/495] running...
#   [Batch 390/495] running...
#   [Batch 395/495] running...
#   [Batch 400/495] running...
#   [Batch 405/495] running...
#   [Batch 410/495] running...
#   [Batch 415/495] running...
#   [Batch 420/495] running...
#   [Batch 425/495] running...
#   [Batch 430/495] running...
#   [Batch 435/495] running...
#   [Batch 440/495] running...
#   [Batch 445/495] running...
#   [Batch 450/495] running...
#   [Batch 455/495] running...
#   [Batch 460/495] running...
#   [Batch 465/495] running...
#   [Batch 470/495] running...
#   [Batch 475/495] running...
#   [Batch 480/495] running...
#   [Batch 485/495] running...
#   [Batch 490/495] running...
# Epoch [1/1] Train Loss: 1.5245, Train Acc: 0.4895 Val Loss: 1.2684, Val Acc: 0.5705 Time: 1086.06s

# %%
class BaselineCNN(nn.Module):
  def __init__(self):

    super().__init__()

    self.conv1 = nn.Conv2d(3,32, kernel_size=3, stride=1,padding=1) #32,224,224
    self.pool = nn.MaxPool2d(2,2)                 #32,112,112
    self.conv2 = nn.Conv2d(32,64, kernel_size=3, stride=1, padding=1) #64,112,112
    #after pooling 64,56,56
    self.conv3 = nn.Conv2d(64,128, kernel_size=3, stride=1, padding=1) #128,56,56
    # after pooling 128, 28,28

    self.fc1 = nn.Linear(128*28*28, 256)
    self.fc2 = nn.Linear(256, 10)

    self.relu = nn.ReLU()
    self.drop = nn.Dropout(0.5)

  def forward(self, x):
    #conv1
    x = self.conv1(x)
    x = self.relu(x)
    x = self.pool(x)

    #conv2 + relu + pool
    x = self.pool(self.relu(self.conv2(x)))

    #conv3 + relu + pool
    x = self.pool(self.relu(self.conv3(x)))

    #flatten
    x = x.view(-1, 128*28*28)

    #fc1+relu+dropout
    x = self.fc1(x)
    x = self.relu(x)
    x = self.drop(x)

    #output
    x=self.fc2(x)

    return x



#initializing model, loss, optimizer
model = BaselineCNN().to(device)

# compute class weights from dataset
labels = [label for _, label in full_dataset.samples]
class_counts = np.bincount(labels)
class_weights = torch.tensor(1.0 / class_counts, dtype=torch.float).to(device)
# Sampler = works with NumPy/Python arrays → PyTorch converts internally.
# Loss function = strictly requires torch.Tensor on the right device.

# weighted loss (to handle imbalance)
criterion = nn.CrossEntropyLoss(weight=class_weights)


optimizer = optim.Adam(model.parameters(), lr=0.001)

#
import time
#trainingLoop
epochs = 5
for epoch in range(epochs):

  train_loss, train_acc = train_an_epoch(model, train_loader, criterion, optimizer, device)
  val_loss, val_acc = evaluate(model, val_loader, criterion, device)

  print(f"Epoch [{epoch+1}/{epochs}] "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
# Out:
#   [Batch 5/495] running...
#   [Batch 10/495] running...
#   [Batch 15/495] running...
#   [Batch 20/495] running...
#   [Batch 25/495] running...
#   [Batch 30/495] running...
#   [Batch 35/495] running...
#   [Batch 40/495] running...
#   [Batch 45/495] running...
#   [Batch 50/495] running...
#   [Batch 55/495] running...
#   [Batch 60/495] running...
#   [Batch 65/495] running...
#   [Batch 70/495] running...
#   [Batch 75/495] running...
#   [Batch 80/495] running...
#   [Batch 85/495] running...
#   [Batch 90/495] running...
#   [Batch 95/495] running...
#   [Batch 100/495] running...
#   [Batch 105/495] running...
#   [Batch 110/495] running...
#   [Batch 115/495] running...
#   [Batch 120/495] running...
#   [Batch 125/495] running...
#   [Batch 130/495] running...
#   [Batch 135/495] running...
#   [Batch 140/495] running...
#   [Batch 145/495] running...
#   [Batch 150/495] running...
#   [Batch 155/495] running...
#   [Batch 160/495] running...
#   [Batch 165/495] running...
#   [Batch 170/495] running...
#   [Batch 175/495] running...
#   [Batch 180/495] running...
#   [Batch 185/495] running...
#   [Batch 190/495] running...
#   [Batch 195/495] running...
#   [Batch 200/495] running...
#   [Batch 205/495] running...
#   [Batch 210/495] running...
#   [Batch 215/495] running...
#   [Batch 220/495] running...
#   [Batch 225/495] running...
#   [Batch 230/495] running...
#   [Batch 235/495] running...
#   [Batch 240/495] running...
#   [Batch 245/495] running...
#   [Batch 250/495] running...
#   [Batch 255/495] running...
#   [Batch 260/495] running...
#   [Batch 265/495] running...
#   [Batch 270/495] running...
#   [Batch 275/495] running...
#   [Batch 280/495] running...
#   [Batch 285/495] running...
#   [Batch 290/495] running...
#   [Batch 295/495] running...
#   [Batch 300/495] running...
#   [Batch 305/495] running...
#   [Batch 310/495] running...
#   [Batch 315/495] running...
#   [Batch 320/495] running...
#   [Batch 325/495] running...
#   [Batch 330/495] running...
#   [Batch 335/495] running...
#   [Batch 340/495] running...
#   [Batch 345/495] running...
#   [Batch 350/495] running...
#   [Batch 355/495] running...
#   [Batch 360/495] running...
#   [Batch 365/495] running...
#   [Batch 370/495] running...
#   [Batch 375/495] running...
#   [Batch 380/495] running...
#   [Batch 385/495] running...
#   [Batch 390/495] running...
#   [Batch 395/495] running...
#   [Batch 400/495] running...
#   [Batch 405/495] running...
#   [Batch 410/495] running...
#   [Batch 415/495] running...
#   [Batch 420/495] running...
#   [Batch 425/495] running...
#   [Batch 430/495] running...
#   [Batch 435/495] running...
#   [Batch 440/495] running...
#   [Batch 445/495] running...
#   [Batch 450/495] running...
#   [Batch 455/495] running...
#   [Batch 460/495] running...
#   [Batch 465/495] running...
#   [Batch 470/495] running...
#   [Batch 475/495] running...
#   [Batch 480/495] running...
#   [Batch 485/495] running...
#   [Batch 490/495] running...
#   [Batch 495/495] running...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1781265692.py in <cell line: 0>()
#      67
#      68   train_loss, train_acc = train_an_epoch(model, train_loader, criterion, optimizer, device)
# ---> 69   val_loss, val_acc = evaluate(model, val_loader, criterion, device)
#      70
#      71   print(f"Epoch [{epoch+1}/{epochs}] "
#
# /tmp/ipython-input-2628453365.py in evaluate(model, dataloader, criterion, device)
#      32
#      33   with torch.no_grad():
# ---> 34     for images, labels in dataloader:
#      35       images, labels = images.to(device), labels.to(device)
#      36
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     732                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733                 self._reset()  # type: ignore[call-arg]
# --> 734             data = self._next_data()
#     735             self._num_yielded += 1
#     736             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     788     def _next_data(self):
#     789         index = self._next_index()  # may raise StopIteration
# --> 790         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791         if self._pin_memory:
#     792             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      48         if self.auto_collation:
#      49             if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
#      52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataset.py in __getitems__(self, indices)
#     414             return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     415         else:
# --> 416             return [self.dataset[self.indices[idx]] for idx in indices]
#     417
#     418     def __len__(self):
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     243         """
#     244         path, target = self.samples[index]
# --> 245         sample = self.loader(path)
#     246         if self.transform is not None:
#     247             sample = self.transform(sample)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in default_loader(path)
#     282         return accimage_loader(path)
#     283     else:
# --> 284         return pil_loader(path)
#     285
#     286
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in pil_loader(path)
#     261     # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
#     262     with open(path, "rb") as f:
# --> 263         img = Image.open(f)
#     264         return img.convert("RGB")
#     265
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3522         exclusive_fp = True
#    3523
# -> 3524     prefix = fp.read(16)
#    3525
#    3526     preinit()
#
# KeyboardInterrupt:

# %%
#resnet
from torchvision import models

class ResNet50_Custom(nn.Module):
  def __init__(self, num_classes=10):
    super().__init__()

    #loading pretained resnet50
    base_model = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)

    #freeqzing all conv layers
    for param in base_model.parameters():
      param.requires_grad = False

    # Save in_features BEFORE replacing fc
    num_features = base_model.fc.in_features

    #keeping everything except the final fc layer
    self.features = base_model  #fullModel
    self.features.fc = nn.Identity()  #removed og fc

    #defining custom dense layers
    self.fc1 = nn.Linear(num_features, 512)
    self.relu = nn.ReLU()
    self.drop = nn.Dropout(0.5)
    self.fc2 = nn.Linear(512, num_classes)

  def forward(self, x):
    #extracting features using resNet backbone
    x = self.features(x)  # output shape: (batch_size, 2048)

    #custom dense layers
    x = self.fc1(x)
    x = self.relu(x)
    x = self.drop(x)
    x = self.fc2(x)
    return x

model = ResNet50_Custom(num_classes=len(full_dataset.classes)).to(device)

labels = [label for _, label in full_dataset.samples]
class_counts = np.bincount(labels)
class_weights = torch.tensor(1.0/class_counts, dtype=torch.float).to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 129MB/s]

# %%
# Training loop
epochs = 10
for epoch in range(epochs):
    train_loss, train_acc = train_an_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_acc = evaluate(model, val_loader, criterion, device)

    print(f"Epoch [{epoch+1}/{epochs}] "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
# Out:
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [1/10] Train Loss: 0.6261, Train Acc: 0.8162 Val Loss: 0.3682, Val Acc: 0.8892
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [2/10] Train Loss: 0.4513, Train Acc: 0.8622 Val Loss: 0.3262, Val Acc: 0.8965
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [3/10] Train Loss: 0.4012, Train Acc: 0.8770 Val Loss: 0.3578, Val Acc: 0.8755
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [4/10] Train Loss: 0.3779, Train Acc: 0.8849 Val Loss: 0.2890, Val Acc: 0.9170
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [5/10] Train Loss: 0.3557, Train Acc: 0.8909 Val Loss: 0.3064, Val Acc: 0.9122
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [6/10] Train Loss: 0.3492, Train Acc: 0.8952 Val Loss: 0.3072, Val Acc: 0.8973
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [7/10] Train Loss: 0.3459, Train Acc: 0.8923 Val Loss: 0.2762, Val Acc: 0.9142
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [8/10] Train Loss: 0.3250, Train Acc: 0.8968 Val Loss: 0.2720, Val Acc: 0.9155
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [9/10] Train Loss: 0.3202, Train Acc: 0.9011 Val Loss: 0.2994, Val Acc: 0.9249
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [10/10] Train Loss: 0.2976, Train Acc: 0.9060 Val Loss: 0.2781, Val Acc: 0.9282

# %%
from torchvision import models

class MobileNetV2_Custom(nn.Module):
  def __init__(self, num_classes=10):
    super().__init__()

    base_model = models.mobilenet_v2(weights=models.MobileNet_V2_Weights.IMAGENET1K_V1)

    for param in base_model.parameters():
      param.requires_grad = False

    num_features = base_model.classifier[1].in_features

    self.features = base_model.features

    self.fc1 = nn.Linear(num_features, 256)
    self.relu = nn.ReLU()
    self.drop = nn.Dropout(0.5)
    self.fc2 = nn.Linear(256, num_classes)

  def forward(self, x):
    # extracting features by help of backbone of this model
    x = self.features(x)    #(batch_size, 1280,7,7)
    x = x.mean([2,3])     #Global average pooling -> (batch_size,1280)

    x = self.fc1(x)
    x = self.relu(x)
    x = self.drop(x)

    x = self.fc2(x)

    return x


#initializing
model = MobileNetV2_Custom(num_classes=len(full_dataset.classes)).to(device)

labels = [label for _, label in full_dataset.samples]
class_counts = np.bincount(labels)
class_weights = torch.tensor(1.0/class_counts, dtype = torch.float).to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 78.1MB/s]

# %%
#training loop

epochs = 10
for epoch in range(epochs):

    train_loss, train_acc = train_an_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_acc = evaluate(model, val_loader, criterion, device)

    print(f"Epoch [{epoch+1}/{epochs}] "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
# Out:
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [1/10] Train Loss: 0.6649, Train Acc: 0.8030 Val Loss: 0.3566, Val Acc: 0.8925
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [2/10] Train Loss: 0.4323, Train Acc: 0.8679 Val Loss: 0.3597, Val Acc: 0.8978
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [3/10] Train Loss: 0.3929, Train Acc: 0.8809 Val Loss: 0.3014, Val Acc: 0.9036
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [4/10] Train Loss: 0.3706, Train Acc: 0.8854 Val Loss: 0.2974, Val Acc: 0.9049
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [5/10] Train Loss: 0.3582, Train Acc: 0.8853 Val Loss: 0.2943, Val Acc: 0.9013
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [6/10] Train Loss: 0.3337, Train Acc: 0.8976 Val Loss: 0.2824, Val Acc: 0.9115
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [7/10] Train Loss: 0.3380, Train Acc: 0.8957 Val Loss: 0.2646, Val Acc: 0.9180
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [8/10] Train Loss: 0.3314, Train Acc: 0.8966 Val Loss: 0.2715, Val Acc: 0.9193
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [9/10] Train Loss: 0.3221, Train Acc: 0.8966 Val Loss: 0.2812, Val Acc: 0.9196
#   [Batch 32/495] running...
#   [Batch 64/495] running...
#   [Batch 96/495] running...
#   [Batch 128/495] running...
#   [Batch 160/495] running...
#   [Batch 192/495] running...
#   [Batch 224/495] running...
#   [Batch 256/495] running...
#   [Batch 288/495] running...
#   [Batch 320/495] running...
#   [Batch 352/495] running...
#   [Batch 384/495] running...
#   [Batch 416/495] running...
#   [Batch 448/495] running...
#   [Batch 480/495] running...
# Epoch [10/10] Train Loss: 0.3220, Train Acc: 0.9002 Val Loss: 0.2675, Val Acc: 0.9233

# %%
#efficientnetB0

class EfficientNetB0_Custom(nn.Module):
  def __init__(self, num_classes=10):
    super().__init__()

    base_model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.IMAGENET1K_V1)

    for param in base_model.features.parameters():
      param.requires_grad = False

    num_features = base_model.classifier[1].in_features

    self.features = base_model.features

    #custom
    self.fc1 = nn.Linear(num_features, 256)
    self.relu = nn.ReLU()
    self.drop = nn.Dropout(0.5)
    self.fc2 = nn.Linear(256, num_classes)

  def forward(self, x):
    #backbone
    x = self.features(x)     # (batch_size, 1280, 7, 7)
    x = x.mean([2,3])

    x = self.fc1(x)
    x = self.relu(x)
    x = self.drop(x)

    x = self.fc2(x)

    return x


#initi
model = EfficientNetB0_Custom(num_classes=len(full_dataset.classes)).to(device)

labels = [label for _, label in full_dataset.samples]
class_counts = np.bincount(labels)
class_weights = torch.tensor(1.0/class_counts, dtype = torch.float).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 104MB/s]

# %%
# Training Loop
epochs = 10
for epoch in range(epochs):

    train_loss, train_acc = train_an_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_acc = evaluate(model, val_loader, criterion, device)

    print(f"Epoch [{epoch+1}/{epochs}] "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2031327718.py in <cell line: 0>()
#       3 for epoch in range(epochs):
#       4
# ----> 5     train_loss, train_acc = train_an_epoch(model, train_loader, criterion, optimizer, device)
#       6     val_loss, val_acc = evaluate(model, val_loader, criterion, device)
#       7
#
# /tmp/ipython-input-1753769443.py in train_an_epoch(model, dataloader, criterion, optimizer, device)
#       9
#      10     optimizer.zero_grad()
# ---> 11     outputs = model(images)
#      12     loss = criterion(outputs,labels)
#      13     loss.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /tmp/ipython-input-2681160364.py in forward(self, x)
#      22   def forward(self, x):
#      23     #backbone
# ---> 24     x = self.features(x)     # (batch_size, 1280, 7, 7)
#      25     x = x.mean([2,3])
#      26
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     242     def forward(self, input):
#     243         for module in self:
# --> 244             input = module(input)
#     245         return input
#     246
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     242     def forward(self, input):
#     243         for module in self:
# --> 244             input = module(input)
#     245         return input
#     246
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/efficientnet.py in forward(self, input)
#     163
#     164     def forward(self, input: Tensor) -> Tensor:
# --> 165         result = self.block(input)
#     166         if self.use_res_connect:
#     167             result = self.stochastic_depth(result)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     242     def forward(self, input):
#     243         for module in self:
# --> 244             input = module(input)
#     245         return input
#     246
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     242     def forward(self, input):
#     243         for module in self:
# --> 244             input = module(input)
#     245         return input
#     246
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#     432
#     433     def forward(self, input: Tensor) -> Tensor:
# --> 434         return F.silu(input, inplace=self.inplace)
#     435
#     436     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py in silu(input, inplace)
#    2372         return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2373     if inplace:
# -> 2374         return torch._C._nn.silu_(input)
#    2375     return torch._C._nn.silu(input)
#    2376
#
# KeyboardInterrupt:

# %%
#googlenet

class GoogleNet_Custom(nn.Module):
  def __init__(self, num_classes=10):
    super().__init__()

    base_model = models.googlenet(weights=models.GoogLeNet_Weights.IMAGENET1K_V1, aux_logits = True)

    # Disable auxiliary classifiers so they don’t affect forward()
    base_model.aux1 = nn.Identity()
    base_model.aux2 = nn.Identity()

    for param in base_model.parameters():
      param.requires_grad = False

    num_features = base_model.fc.in_features

    self.features = base_model
    self.features.fc = nn.Identity()

    self.fc1 = nn.Linear(num_features, 256)
    self.relu = nn.ReLU()
    self.drop = nn.Dropout(0.5)
    self.fc2 = nn.Linear(256, num_classes)

  def forward(self, x):

    x = self.features(x)    #(batchsize,1024)

    x = self.fc1(x)
    x = self.relu(x)
    x = self.drop(x)

    x =self.fc2(x)

    return x


#ini
model = GoogleNet_Custom(num_classes=len(full_dataset.classes)).to(device)

labels = [label for _, label in full_dataset.samples]
class_counts = np.bincount(labels)
class_weights = torch.tensor(1.0 / class_counts, dtype=torch.float).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 145MB/s]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/googlenet.py:341: UserWarning: auxiliary heads in the pretrained googlenet model are NOT pretrained, so make sure to train them
#   warnings.warn(

# %%
# Training Loop
epochs = 10
for epoch in range(epochs):
    start = time.time()

    train_loss, train_acc = train_an_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_acc = evaluate(model, val_loader, criterion, device)

    print(f"Epoch [{epoch+1}/{epochs}] "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

# %%
class VGG16_Custom(nn.Module):
    def __init__(self, num_classes=10):
        super(VGG16_Custom, self).__init__()

        # Load pretrained VGG16
        base_model = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)

        # Freeze feature extractor
        for param in base_model.features.parameters():
            param.requires_grad = False

        # Get input features of classifier
        num_features = base_model.classifier[6].in_features

        # Replace classifier with custom dense head
        self.features = base_model.features
        self.avgpool = base_model.avgpool

        self.fc1 = nn.Linear(num_features, 256)
        self.relu = nn.ReLU()
        self.drop = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x):     #Input: [32, 3, 224, 224]
        x = self.features(x)    #[32, 512, 7, 7]
        x = self.avgpool(x)     #[32, 512, 7, 7]
        x = torch.flatten(x, 1)   # flatten to (batch_size, num_features)-[32,25088]

        x = self.fc1(x) #32
        x = self.relu(x)
        x = self.drop(x)
        x = self.fc2(x)
        return x


# Initialize model
model = VGG16_Custom(num_classes=len(full_dataset.classes)).to(device)

# Weighted loss
labels = [label for _, label in full_dataset.samples]
class_counts = np.bincount(labels)
class_weights = torch.tensor(1.0 / class_counts, dtype=torch.float).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:05<00:00, 107MB/s]

# %%
# Training loop
epochs = 10
for epoch in range(epochs):
    start = time.time()

    train_loss, train_acc = train_an_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_acc = evaluate(model, val_loader, criterion, device)

    duration = time.time() - start
    print(f"Epoch [{epoch+1}/{epochs}] "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f} "
          f"Time: {duration:.2f}s")

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Reload saved ResNet50 model
best_model = ResNet50_Custom(num_classes=len(full_dataset.classes)).to(device)
best_model.load_state_dict(
    torch.load("/content/drive/MyDrive/RecycleVision/models/resnet50_best.pth",
               map_location=torch.device("cpu"))
)
best_model.eval()

y_true, y_pred = [], []

# Run inference on validation set
with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = best_model(images)
        _, preds = torch.max(outputs, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=full_dataset.classes))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=full_dataset.classes,
            yticklabels=full_dataset.classes)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      battery       0.93      0.99      0.96       199
#   biological       0.98      1.00      0.99       203
#    cardboard       0.97      0.94      0.96       383
#      clothes       0.99      0.99      0.99      1080
#        glass       0.98      0.89      0.93       599
#        metal       0.84      0.93      0.89       203
#        paper       0.93      0.92      0.93       326
#      plastic       0.86      0.93      0.89       390
#        shoes       0.96      0.98      0.97       385
#        trash       0.90      0.92      0.91       185
#
#     accuracy                           0.95      3953
#    macro avg       0.93      0.95      0.94      3953
# weighted avg       0.95      0.95      0.95      3953
